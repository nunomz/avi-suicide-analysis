# %%
import pandas as pd

# %% [markdown]
# ## upload all datasets

# %%
#df_mortes = pd.read_csv("dados/our-world-in-data/annual-number-of-deaths-by-cause.csv") #7273
#df_ratio = pd.read_csv("dados\our-world-in-data\share-deaths-suicide.csv")
#df_mf_ratio = pd.read_csv("dados\our-world-in-data\Male-Female-Ratio-of-Suicide-Rates.csv") #6188
#df_mf = pd.read_csv("dados\our-world-in-data\male-vs-female-suicide.csv")
#df_pesticide nao estamos a usar
#df_mf_ratio = pd.read_csv("dados\our-world-in-data\suicide-death-rates-by-sex.csv")
#df_raties = pd.read_csv("dados\our-world-in-data\suicide-death-rates.csv")
#suicide rate 1990 nao entendo 
#df_firearms = pd.read_csv("dados\our-world-in-data\suicide-rate-by-firearm.csv")
#df_ages = pd.read_csv("dados\our-world-in-data\suicide-rates-by-age-detailed.csv")
df_continents = pd.read_csv("dados\our-world-in-data\continents-according-to-our-world-in-data.csv")

# %%
#df_suicidios = df_mortes[['Entity','Code','Year','Deaths - Self-harm - Sex: Both - Age: All Ages (Number)']]
#df_main = pd.merge(df_suicidios,df_mf_ratio,how='inner',on=['Entity','Code','Year'])
#df_main = pd.merge(df_main,df_mf,how='inner',on=['Entity','Code','Year'])
#df_main= pd.merge(df_main,df_ratio,how='inner',on=['Entity','Code','Year'])
#df_main= pd.merge(df_main,df_mf_ratio,how='inner',on=['Entity','Code','Year'])
#df_main= pd.merge(df_main,df_raties,how='inner',on=['Entity','Code','Year'])
#df_main= pd.merge(df_main,df_firearms,how='inner',on=['Entity','Code','Year'])
#df_main= pd.merge(df_main,df_ages,how='inner',on=['Entity','Code','Year'])
#df_main = df_main.drop('Continent', axis=1)
#df_continents = df_continents[['Entity','Code','Continent']]
df_main= pd.merge(df_main,df_continents,how='left',on=['Entity','Code'])

# %%
df_main
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  2007
# 1     Afghanistan  AFG  2008
# 2     Afghanistan  AFG  2009
# 3     Afghanistan  AFG  2011
# 4     Afghanistan  AFG  2012
# ...           ...  ...   ...
# 5427     Zimbabwe  ZWE  2013
# 5428     Zimbabwe  ZWE  2014
# 5429     Zimbabwe  ZWE  2015
# 5430     Zimbabwe  ZWE  2016
# 5431     Zimbabwe  ZWE  2017
#
#       Deaths - Self-harm - Sex: Both - Age: All Ages (Number)  \
# 0                                                1310.0
# 1                                                1330.0
# 2                                                1342.0
# 3                                                1391.0
# 4                                                1413.0
# ...                                                 ...
# 5427                                             2103.0
# 5428                                             2156.0
# 5429                                             2235.0
# ...

# %%
df_main.to_csv('merged_1.csv')
